# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy.interpolate import CubicSpline

matplotlib.rcParams["mathtext.fontset"]="cm";
matplotlib.rcParams["font.family"]="STIXGeneral";
x = np.array([5.5,5.6,5.7,5.8,5.9,6.0,6.1,6.3 ])
d = np.array([1.3013, 1.32983, 1.35837,1.38692,1.41546,1.59075,1.61989,1.68894 ])
s=np.array([0, 0, 0,0,0,0.627079,0.654669,0.714811])
plt.plot(x, d, "o--", markersize=10, color="orange", fillstyle="none", label=r"$\Delta_d$")
plt.plot(x, s, "o--", markersize=10, color="cornflowerblue", fillstyle="none", label=r"$\Delta_s$")

plt.xlabel(r"$|V_1/t|$",fontsize=20)

plt.ylabel(r"$\Delta/t$",fontsize=20)


plt.xticks([5.5,5.9,6.2],fontsize=15)
plt.yticks([0,0.5,1,1.5],fontsize=15)


plt.legend(fontsize=20)
plt.tight_layout()
plt.savefig("appendix_fig0.pdf", bbox_inches='tight')
